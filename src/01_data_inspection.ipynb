# %%
import pandas as pd
import os

# %%
BASE_PATH = r"C:\Users\manoj\Downloads\Network_Datasets"

TON_PATH = os.path.join(BASE_PATH, "TON IOT Dataset")
CIC_PATH = os.path.join(BASE_PATH, "CIC IDS Dataset")
UNSW_PATH = os.path.join(BASE_PATH, "UNSW Dataset")

print("Paths loaded successfully")
# Out:
# Paths loaded successfully

# %%
print("TON Files:", len(os.listdir(TON_PATH)))
print(os.listdir(TON_PATH)[:3])

print("\nCIC Files:", len(os.listdir(CIC_PATH)))
print(os.listdir(CIC_PATH))

print("\nUNSW Files:", os.listdir(UNSW_PATH))
# Out:
# TON Files: 23
# ['Network_dataset_1.csv', 'Network_dataset_10.csv', 'Network_dataset_11.csv']
#
# CIC Files: 8
# ['Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv', 'Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv', 'Friday-WorkingHours-Morning.pcap_ISCX.csv', 'Monday-WorkingHours.pcap_ISCX.csv', 'Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv', 'Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv', 'Tuesday-WorkingHours.pcap_ISCX.csv', 'Wednesday-workingHours.pcap_ISCX.csv']
#
# UNSW Files: ['UNSW_NB15_testing-set.csv', 'UNSW_NB15_training-set.csv']

# %%
ton_file = os.path.join(TON_PATH, os.listdir(TON_PATH)[0])

ton_sample = pd.read_csv(ton_file, nrows=1000, low_memory=False)

print("TON Columns:\n", ton_sample.columns.tolist())
ton_sample.head()
# Out:
# TON Columns:
#  ['ts', 'src_ip', 'src_port', 'dst_ip', 'dst_port', 'proto', 'service', 'duration', 'src_bytes', 'dst_bytes', 'conn_state', 'missed_bytes', 'src_pkts', 'src_ip_bytes', 'dst_pkts', 'dst_ip_bytes', 'dns_query', 'dns_qclass', 'dns_qtype', 'dns_rcode', 'dns_AA', 'dns_RD', 'dns_RA', 'dns_rejected', 'ssl_version', 'ssl_cipher', 'ssl_resumed', 'ssl_established', 'ssl_subject', 'ssl_issuer', 'http_trans_depth', 'http_method', 'http_uri', 'http_referrer', 'http_version', 'http_request_body_len', 'http_response_body_len', 'http_status_code', 'http_user_agent', 'http_orig_mime_types', 'http_resp_mime_types', 'weird_name', 'weird_addl', 'weird_notice', 'label', 'type']
#            ts         src_ip  src_port         dst_ip  dst_port proto service  \
# 0  1554198358    3.122.49.24      1883  192.168.1.152     52976   tcp       -
# 1  1554198358   192.168.1.79     47260  192.168.1.255     15600   udp       -
# ...

# %%
cic_file = os.path.join(CIC_PATH, os.listdir(CIC_PATH)[0])

cic_sample = pd.read_csv(cic_file, nrows=1000, low_memory=False)

print("CIC Columns:\n", cic_sample.columns.tolist())
cic_sample.head()
# Out:
# CIC Columns:
# ...

# %%
unsw_file = os.path.join(UNSW_PATH, "UNSW_NB15_training-set.csv")

unsw_sample = pd.read_csv(unsw_file, nrows=1000)

print("UNSW Columns:\n", unsw_sample.columns.tolist())
unsw_sample.head()
# Out:
# UNSW Columns:
#  ['id', 'dur', 'proto', 'service', 'state', 'spkts', 'dpkts', 'sbytes', 'dbytes', 'rate', 'sttl', 'dttl', 'sload', 'dload', 'sloss', 'dloss', 'sinpkt', 'dinpkt', 'sjit', 'djit', 'swin', 'stcpb', 'dtcpb', 'dwin', 'tcprtt', 'synack', 'ackdat', 'smean', 'dmean', 'trans_depth', 'response_body_len', 'ct_srv_src', 'ct_state_ttl', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'is_ftp_login', 'ct_ftp_cmd', 'ct_flw_http_mthd', 'ct_src_ltm', 'ct_srv_dst', 'is_sm_ips_ports', 'attack_cat', 'label']
#    id       dur proto service state  spkts  dpkts  sbytes  dbytes       rate  \
# 0   1  0.121478   tcp       -   FIN      6      4     258     172  74.087490
# 1   2  0.649902   tcp       -   FIN     14     38     734   42014  78.473372
# 2   3  1.623129   tcp       -   FIN      8     16     364   13186  14.170161
# 3   4  1.681642   tcp     ftp   FIN     12     12     628     770  13.677108
# ...
